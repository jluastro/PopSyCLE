# %%
import warnings
warnings.filterwarnings('ignore')
from popsycle import synthetic
from popsycle import utils
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table, vstack
import synthpop
import pdb
import time

# %%
sp_mod = synthetic.run_synthpop('huston2025_defaults.synthpop_conf', # set default figuration, then set any overrides as kwargs
                                output_location="synthpop_output",  # where to place the synthpop output
                                obsmag = False, # keep magnitudes in absolute
                                output_filename_pattern="{name_for_output}_l{l_deg:.3f}_b{b_deg:.3f}", #how to name the output
                                name_for_output='synthpopsycle_SPISEA',
                                post_processing_kwargs = [{"name": "popsycle_post_processing"}], # Module to format catalog for PopSyCLE
                                chosen_bands = ['ubv', 'ukirt'],
                                maglim = ['m_ukirt_H', 99, "keep"],
                                combine_system_mags = True,
                                star_generator="SpiseaGenerator",
                                evolution_class={"name":"SpiseaCluster", "block_spisea_prints":False},
                                ifmr_kwargs={"name":"SpiseaIfmr", "spisea_ifmr_name":"IFMR_N20_Sukhbold"},
                                multiplicity_kwargs={"name":"SpiseaMultiplicity", "spisea_multiplicity_name":"MultiplicityResolvedDK"},
                                opt_iso_props=["log_L", "log_Teff", "log_g","log_R", "phase"],
                                extinction_map_kwargs = {"name":"maps_from_dustmaps", "dustmap_name":"marshall"}, #{"name":"surot"}
                                l_deg=1, b_deg=-1.2, field_shape='box', 
                                field_scale=0.06, field_scale_unit='deg', save_data=False
                          )
# Out:
# ################################ Settings #################################
#  792102 - # reading default parameters from
#  792106 - default_config_file =  /u/shepbrooke/code/synthpop/synthpop/config_files/_default.synthpop_conf
#  792109 - # read configuration from
#  792111 - config_file = '/u/shepbrooke/code/synthpop/synthpop/config_files/huston2025_defaults.synthpop_conf'
#
#
# # copy the following to a config file to redo this model generation -------
#  792114 - {
#     "l_set": null,
#     "l_set_type": null,
#     "b_set": null,
#     "b_set_type": null,
#     "name_for_output": "Huston2025",
#     "model_name": "Huston2025",
#     "field_shape": "circle",
#     "field_scale": null,
#     "field_scale_unit": "deg",
#     "random_seed": 440795469,
#     "sun": {
#         "x": -8.178,
#         "y": 0.0,
#         "z": 0.017,
#         "u": 12.9,
#         "v": 245.6,
#         "w": 7.78,
#         "l_apex_deg": 56.24,
#         "b_apex_deg": 22.54
#     },
#     "lsr": {
#         "u_lsr": 1.8,
#         "v_lsr": 233.4,
#         "w_lsr": 0.53
#     },
#     "warp": {
#         "r_warp": 7.72,
#         "amp_warp": 0.06,
#         "amp_warp_pos": null,
#         "amp_warp_neg": null,
#         "alpha_warp": 1.33,
#         "phi_warp_deg": 17.5
#     },
#     "max_distance": 25,
#     "distance_step_size": 0.1,
#     "mass_lims": {
#         "min_mass": 0.08,
#         "max_mass": 100
#     },
#     "N_mc_totmass": 10000,
#     "lost_mass_option": 1,
#     "N_av_mass": 50000,
#     "kinematics_at_the_end": false,
#     "scale_factor": 1,
#     "skip_lowmass_stars": false,
#     "chunk_size": 250000,
#     "star_generator": "SpiseaGenerator",
#     "extinction_map_kwargs": {
#         "name": "maps_from_dustmaps",
#         "dustmap_name": "marshall"
#     },
#     "extinction_law_kwargs": [
#         {
#             "name": "SODC",
#             "R_V": 2.5
#         }
#     ],
#     "evolution_class": {
#         "name": "SpiseaCluster",
#         "block_spisea_prints": false
#     },
#     "ifmr_kwargs": {
#         "name": "SpiseaIfmr",
#         "spisea_ifmr_name": "IFMR_N20_Sukhbold"
#     },
#     "multiplicity_kwargs": {
#         "name": "SpiseaMultiplicity",
#         "spisea_multiplicity_name": "MultiplicityResolvedDK"
#     },
#     "maglim": [
#         "m_ukirt_H",
#         99,
#         "keep"
#     ],
#     "chosen_bands": [
#         "ubv",
#         "ukirt"
#     ],
#     "obsmag": false,
#     "combine_system_mags": true,
#     "opt_iso_props": [
#         "log_L",
#         "log_Teff",
#         "log_g",
#         "log_R",
#         "phase"
#     ],
#     "post_processing_kwargs": [
#         {
#             "name": "popsycle_post_processing"
#         }
#     ],
#     "output_location": "synthpop_output",
#     "output_filename_pattern": "{name_for_output}_l{l_deg:.3f}_b{b_deg:.3f}",
#     "output_file_type": "csv",
#     "overwrite": true
# }
#  792116 - Location or solid_angle_sr are not  defined in the settings! Can not run main() or process_all()
#
#
# ######################### Initialize populations ##########################
#  792128 - read Population files from Huston2025
#
#
# # Population 0;  bulge ----------------------------------------------------
#  792136 - # Initialize Population 0 (bulge) from
#  792138 - pop_file = '/u/shepbrooke/code/synthpop/synthpop/models/Huston2025/bulge.popjson'
#
#
# # Population 1;  halo -----------------------------------------------------
#  792256 - # Initialize Population 1 (halo) from
#  792258 - pop_file = '/u/shepbrooke/code/synthpop/synthpop/models/Huston2025/halo.popjson'
# ** Generating synthpopsycle_SPISEA_l1.000_b-1.200_psc_synthpop_params.txt **
# -- configFile huston2025_defaults.synthpop_conf
# -- nameForOutput synthpopsycle_SPISEA
# -- l 1
# -- b -1.2
# -- fieldScale 0.06
# -- fieldScaleUnit deg
# -- fieldShape box
# # Population 2;  nsd ------------------------------------------------------
#  792350 - # Initialize Population 2 (nsd) from
#  792352 - pop_file = '/u/shepbrooke/code/synthpop/synthpop/models/Huston2025/nsd.popjson'
#
#
# # Population 3;  thick_disk -----------------------------------------------
#  793297 - # Initialize Population 3 (thick_disk) from
#  793299 - pop_file = '/u/shepbrooke/code/synthpop/synthpop/models/Huston2025/thick_disk.popjson'
#
#
# # Population 4;  thin_disk_1 ----------------------------------------------
#  793388 - # Initialize Population 4 (thin_disk_1) from
#  793390 - pop_file = '/u/shepbrooke/code/synthpop/synthpop/models/Huston2025/thin_disk_1.popjson'
#
#
# # Population 5;  thin_disk_2 ----------------------------------------------
#  793491 - # Initialize Population 5 (thin_disk_2) from
#  793493 - pop_file = '/u/shepbrooke/code/synthpop/synthpop/models/Huston2025/thin_disk_2.popjson'
#
#
# # Population 6;  thin_disk_3 ----------------------------------------------
#  793595 - # Initialize Population 6 (thin_disk_3) from
#  793597 - pop_file = '/u/shepbrooke/code/synthpop/synthpop/models/Huston2025/thin_disk_3.popjson'
#
#
# # Population 7;  thin_disk_4 ----------------------------------------------
#  793691 - # Initialize Population 7 (thin_disk_4) from
#  793693 - pop_file = '/u/shepbrooke/code/synthpop/synthpop/models/Huston2025/thin_disk_4.popjson'
#
#
# # Population 8;  thin_disk_5 ----------------------------------------------
#  793793 - # Initialize Population 8 (thin_disk_5) from
#  793795 - pop_file = '/u/shepbrooke/code/synthpop/synthpop/models/Huston2025/thin_disk_5.popjson'
#
#
# # Population 9;  thin_disk_6 ----------------------------------------------
#  793898 - # Initialize Population 9 (thin_disk_6) from
#  793900 - pop_file = '/u/shepbrooke/code/synthpop/synthpop/models/Huston2025/thin_disk_6.popjson'
#
#
# # Population 10;  thin_disk_7 ---------------------------------------------
#  794001 - # Initialize Population 10 (thin_disk_7) from
#  794003 - pop_file = '/u/shepbrooke/code/synthpop/synthpop/models/Huston2025/thin_disk_7.popjson'
#  794099 - # All populations are initialized
#
#
# ############################# Update location #############################
#  794103 - # set location to:
#  794105 - l, b = (0.85 deg, -1.35 deg)
#  794107 - # set field scale to:
#  794109 - field_scale = 2.076e-04 deg
#
#
# ############################# Generate Field ##############################
#  794331 - Evolving test set from population 0 to estimate average initial->final mass ratio
# Keep low mass stars below grid and compact objects
# Found 24 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 40 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 144 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 570 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 1324 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 1682 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 2784 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 3 stars out of mass range
# Found 4213 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
#  803469 - Evolving test set from population 1 to estimate average initial->final mass ratio
# Found 1568 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 25 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 32 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 370 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 3 stars out of mass range
# Found 1779 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 3130 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 2513 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 2114 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 2 stars out of mass range
# Found 1262 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 587 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 414 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 329 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 92 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 29 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 34 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 25 companions out of stellar mass range
#  812802 - Evolving test set from population 2 to estimate average initial->final mass ratio
# Keep low mass stars below grid and compact objects
# Found 42 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 49 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 30 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 127 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 513 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 1183 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1633 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 2 stars out of mass range
# Found 2489 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 8 stars out of mass range
# Found 3688 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 2 stars out of mass range
#  820930 - Evolving test set from population 3 to estimate average initial->final mass ratio
# Found 1362 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 30 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 28 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 303 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 1260 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 4 stars out of mass range
# Found 3225 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 3 stars out of mass range
# Found 3920 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 2300 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 958 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 196 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
#  829512 - Evolving test set from population 4 to estimate average initial->final mass ratio
# Found 31 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 7 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 23 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 19 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 22 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 25 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 17 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 20 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 27 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 25 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 24 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 25 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 23 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 37 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 20 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 15 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 19 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 16 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 21 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 22 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 13 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 28 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 18 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 28 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 31 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 38 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 30 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 27 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 11 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 25 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 3 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 24 companions out of stellar mass range
# Changing to logg=4.50 for met=-0.50 T= 39117 logg=4.29
# Changing to met=-0.50 for met=-0.50 T= 39117 logg=4.29
# Changing to logg=4.50 for met=-0.50 T= 39507 logg=4.28
# Changing to met=-0.50 for met=-0.50 T= 39507 logg=4.28
# Changing to logg=4.50 for met=-0.50 T= 39920 logg=4.28
# Changing to met=-0.50 for met=-0.50 T= 39920 logg=4.28
# Changing to logg=4.50 for met=-0.50 T= 40372 logg=4.28
# Changing to met=-0.50 for met=-0.50 T= 40372 logg=4.28
# Changing to logg=4.50 for met=-0.50 T= 40828 logg=4.28
# Changing to met=-0.50 for met=-0.50 T= 40828 logg=4.28
# Changing to logg=4.50 for met=-0.50 T= 41275 logg=4.27
# Changing to met=-0.50 for met=-0.50 T= 41275 logg=4.27
# Changing to logg=4.50 for met=-0.50 T= 41749 logg=4.27
# Changing to met=-0.50 for met=-0.50 T= 41749 logg=4.27
# Changing to logg=4.50 for met=-0.50 T= 42303 logg=4.27
# Changing to met=-0.50 for met=-0.50 T= 42303 logg=4.27
# Changing to logg=4.50 for met=-0.50 T= 42710 logg=4.27
# Changing to met=-0.50 for met=-0.50 T= 42710 logg=4.27
# Changing to logg=4.50 for met=-0.50 T= 43064 logg=4.27
# Changing to met=-0.50 for met=-0.50 T= 43064 logg=4.27
# Changing to logg=4.50 for met=-0.50 T= 43610 logg=4.26
# Changing to met=-0.50 for met=-0.50 T= 43610 logg=4.26
# Changing to logg=4.50 for met=-0.50 T= 44151 logg=4.26
# Changing to met=-0.50 for met=-0.50 T= 44151 logg=4.26
# Changing to logg=4.50 for met=-0.50 T= 44571 logg=4.26
# Changing to met=-0.50 for met=-0.50 T= 44571 logg=4.26
# Changing to logg=4.50 for met=-0.50 T= 44997 logg=4.25
# Changing to met=-0.50 for met=-0.50 T= 44997 logg=4.25
# Changing to logg=4.50 for met=-0.50 T= 45291 logg=4.25
# Changing to met=-0.50 for met=-0.50 T= 45291 logg=4.25
# Changing to logg=4.50 for met=-0.50 T= 45484 logg=4.25
# Changing to met=-0.50 for met=-0.50 T= 45484 logg=4.25
# Changing to logg=4.50 for met=-0.50 T= 45682 logg=4.25
# Changing to met=-0.50 for met=-0.50 T= 45682 logg=4.25
# Changing to logg=4.50 for met=-0.50 T= 45885 logg=4.25
# Changing to met=-0.50 for met=-0.50 T= 45885 logg=4.25
# Changing to logg=4.50 for met=-0.50 T= 46092 logg=4.25
# Changing to met=-0.50 for met=-0.50 T= 46092 logg=4.25
# Changing to logg=4.50 for met=-0.50 T= 46304 logg=4.25
# Changing to met=-0.50 for met=-0.50 T= 46304 logg=4.25
# Changing to logg=4.50 for met=-0.50 T= 46522 logg=4.25
# Changing to met=-0.50 for met=-0.50 T= 46522 logg=4.25
# Changing to logg=5.00 for met=-0.50 T= 49883 logg=4.23
# Changing to met=-0.50 for met=-0.50 T= 49883 logg=4.23
# Changing to T= 50000 for met=-0.50 T= 50199 logg=4.23
# Changing to logg=5.00 for met=-0.50 T= 50199 logg=4.23
# Changing to met=-0.50 for met=-0.50 T= 50199 logg=4.23
# Changing to T= 50000 for met=-0.50 T= 50495 logg=4.22
# Changing to logg=5.00 for met=-0.50 T= 50495 logg=4.22
# Changing to met=-0.50 for met=-0.50 T= 50495 logg=4.22
# Changing to T= 50000 for met=-0.50 T= 50690 logg=4.22
# Changing to logg=5.00 for met=-0.50 T= 50690 logg=4.22
# Changing to met=-0.50 for met=-0.50 T= 50690 logg=4.22
# Changing to T= 50000 for met=-0.50 T= 50879 logg=4.22
# Changing to logg=5.00 for met=-0.50 T= 50879 logg=4.22
# Changing to met=-0.50 for met=-0.50 T= 50879 logg=4.22
# Changing to T= 50000 for met=-0.50 T= 51065 logg=4.22
# Changing to logg=5.00 for met=-0.50 T= 51065 logg=4.22
# Changing to met=-0.50 for met=-0.50 T= 51065 logg=4.22
# Changing to T= 50000 for met=-0.50 T= 51323 logg=4.22
# Changing to logg=5.00 for met=-0.50 T= 51323 logg=4.22
# Changing to met=-0.50 for met=-0.50 T= 51323 logg=4.22
# Changing to T= 50000 for met=-0.50 T= 51618 logg=4.22
# Changing to logg=5.00 for met=-0.50 T= 51618 logg=4.22
# Changing to met=-0.50 for met=-0.50 T= 51618 logg=4.22
# Changing to T= 50000 for met=-0.50 T= 52132 logg=4.22
# Changing to logg=5.00 for met=-0.50 T= 52132 logg=4.22
# Changing to met=-0.50 for met=-0.50 T= 52132 logg=4.22
# Isochrone generation took 14.516537 s.
# Making photometry for isochrone: log(t) = 5.65  AKs = 0.00  dist = 10
#      Starting at:  2026-01-15 19:51:22.585026   Usually takes ~5 minutes
# Starting filter: ubv,B   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.100 Msun  T =  3215 K  m_ubv_B = 10.80
# M =   4.012 Msun  T =  7045 K  m_ubv_B = -0.58
# M =  11.989 Msun  T = 29526 K  m_ubv_B = -2.60
# Starting filter: ubv,I   Elapsed time: 2.84 seconds
# Starting synthetic photometry
# M =   0.100 Msun  T =  3215 K  m_ubv_I = 6.56
# M =   4.012 Msun  T =  7045 K  m_ubv_I = -1.26
# M =  11.989 Msun  T = 29526 K  m_ubv_I = -1.97
# Starting filter: ubv,R   Elapsed time: 5.55 seconds
# Starting synthetic photometry
# M =   0.100 Msun  T =  3215 K  m_ubv_R = 8.38
# M =   4.012 Msun  T =  7045 K  m_ubv_R = -1.04
# M =  11.989 Msun  T = 29526 K  m_ubv_R = -2.22
# Starting filter: ubv,U   Elapsed time: 8.21 seconds
# Starting synthetic photometry
# M =   0.100 Msun  T =  3215 K  m_ubv_U = 11.75
# M =   4.012 Msun  T =  7045 K  m_ubv_U = -0.52
# M =  11.989 Msun  T = 29526 K  m_ubv_U = -3.59
# Starting filter: ubv,V   Elapsed time: 11.17 seconds
# Starting synthetic photometry
# M =   0.100 Msun  T =  3215 K  m_ubv_V = 9.32
# M =   4.012 Msun  T =  7045 K  m_ubv_V = -0.87
# M =  11.989 Msun  T = 29526 K  m_ubv_V = -2.33
# Starting filter: ukirt,H   Elapsed time: 14.02 seconds
# Starting synthetic photometry
# M =   0.100 Msun  T =  3215 K  m_ukirt_H = 4.80
# M =   4.012 Msun  T =  7045 K  m_ukirt_H = -1.63
# M =  11.989 Msun  T = 29526 K  m_ukirt_H = -1.57
# Starting filter: ukirt,J   Elapsed time: 16.35 seconds
# Starting synthetic photometry
# M =   0.100 Msun  T =  3215 K  m_ukirt_J = 5.42
# M =   4.012 Msun  T =  7045 K  m_ukirt_J = -1.48
# M =  11.989 Msun  T = 29526 K  m_ukirt_J = -1.67
# Starting filter: ukirt,K   Elapsed time: 17.99 seconds
# Starting synthetic photometry
# M =   0.100 Msun  T =  3215 K  m_ukirt_K = 4.51
# M =   4.012 Msun  T =  7045 K  m_ukirt_K = -1.65
# M =  11.989 Msun  T = 29526 K  m_ukirt_K = -1.47
#       Time taken: 20.30 seconds
# Keep low mass stars below grid and compact objects
# Found 32 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 5 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 20 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 36 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 19 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 12 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 35 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 28 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 28 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 27 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 16 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 33 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 16 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 10 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 18 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 19 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 35 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 19 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 12 companions out of stellar mass range
# Changing to logg=4.50 for met=-0.50 T= 39032 logg=4.27
# Changing to met=-0.50 for met=-0.50 T= 39032 logg=4.27
# Changing to logg=4.50 for met=-0.50 T= 39441 logg=4.26
# Changing to met=-0.50 for met=-0.50 T= 39441 logg=4.26
# Changing to logg=4.50 for met=-0.50 T= 39883 logg=4.26
# Changing to met=-0.50 for met=-0.50 T= 39883 logg=4.26
# Changing to logg=4.50 for met=-0.50 T= 40360 logg=4.26
# Changing to met=-0.50 for met=-0.50 T= 40360 logg=4.26
# Changing to logg=4.50 for met=-0.50 T= 40827 logg=4.25
# Changing to met=-0.50 for met=-0.50 T= 40827 logg=4.25
# Changing to logg=4.50 for met=-0.50 T= 41278 logg=4.25
# Changing to met=-0.50 for met=-0.50 T= 41278 logg=4.25
# Changing to logg=4.50 for met=-0.50 T= 41835 logg=4.25
# Changing to met=-0.50 for met=-0.50 T= 41835 logg=4.25
# Changing to logg=4.50 for met=-0.50 T= 42433 logg=4.24
# Changing to met=-0.50 for met=-0.50 T= 42433 logg=4.24
# Changing to logg=4.50 for met=-0.50 T= 42765 logg=4.24
# Changing to met=-0.50 for met=-0.50 T= 42765 logg=4.24
# Changing to logg=4.50 for met=-0.50 T= 43096 logg=4.24
# Changing to met=-0.50 for met=-0.50 T= 43096 logg=4.24
# Changing to logg=4.50 for met=-0.50 T= 43829 logg=4.23
# Changing to met=-0.50 for met=-0.50 T= 43829 logg=4.23
# Changing to logg=4.50 for met=-0.50 T= 44257 logg=4.23
# Changing to met=-0.50 for met=-0.50 T= 44257 logg=4.23
# Changing to logg=4.50 for met=-0.50 T= 44692 logg=4.23
# Changing to met=-0.50 for met=-0.50 T= 44692 logg=4.23
# Changing to logg=4.50 for met=-0.50 T= 45097 logg=4.22
# Changing to met=-0.50 for met=-0.50 T= 45097 logg=4.22
# Changing to logg=4.50 for met=-0.50 T= 45335 logg=4.22
# Changing to met=-0.50 for met=-0.50 T= 45335 logg=4.22
# Changing to logg=4.50 for met=-0.50 T= 45579 logg=4.22
# Changing to met=-0.50 for met=-0.50 T= 45579 logg=4.22
# Changing to logg=4.50 for met=-0.50 T= 45831 logg=4.22
# Changing to met=-0.50 for met=-0.50 T= 45831 logg=4.22
# Changing to logg=4.50 for met=-0.50 T= 46090 logg=4.22
# Changing to met=-0.50 for met=-0.50 T= 46090 logg=4.22
# Changing to logg=4.50 for met=-0.50 T= 46358 logg=4.22
# Changing to met=-0.50 for met=-0.50 T= 46358 logg=4.22
# Changing to logg=4.50 for met=-0.50 T= 47028 logg=4.21
# Changing to met=-0.50 for met=-0.50 T= 47028 logg=4.21
# Changing to logg=5.00 for met=-0.50 T= 49820 logg=4.19
# Changing to met=-0.50 for met=-0.50 T= 49820 logg=4.19
# Changing to T= 50000 for met=-0.50 T= 50150 logg=4.19
# Changing to logg=5.00 for met=-0.50 T= 50150 logg=4.19
# Changing to met=-0.50 for met=-0.50 T= 50150 logg=4.19
# Changing to T= 50000 for met=-0.50 T= 50454 logg=4.19
# Changing to logg=5.00 for met=-0.50 T= 50454 logg=4.19
# Changing to met=-0.50 for met=-0.50 T= 50454 logg=4.19
# Changing to T= 50000 for met=-0.50 T= 50763 logg=4.19
# Changing to logg=5.00 for met=-0.50 T= 50763 logg=4.19
# Changing to met=-0.50 for met=-0.50 T= 50763 logg=4.19
# Changing to T= 50000 for met=-0.50 T= 51058 logg=4.19
# Changing to logg=5.00 for met=-0.50 T= 51058 logg=4.19
# Changing to met=-0.50 for met=-0.50 T= 51058 logg=4.19
# Changing to T= 50000 for met=-0.50 T= 51363 logg=4.19
# Changing to logg=5.00 for met=-0.50 T= 51363 logg=4.19
# Changing to met=-0.50 for met=-0.50 T= 51363 logg=4.19
# Changing to T= 50000 for met=-0.50 T= 51648 logg=4.18
# Changing to logg=5.00 for met=-0.50 T= 51648 logg=4.18
# Changing to met=-0.50 for met=-0.50 T= 51648 logg=4.18
# Isochrone generation took 14.760627 s.
# Making photometry for isochrone: log(t) = 5.95  AKs = 0.00  dist = 10
#      Starting at:  2026-01-15 19:51:58.679964   Usually takes ~5 minutes
# Starting filter: ubv,B   Elapsed time: 0.00 seconds
# Starting synthetic photometry
# M =   0.100 Msun  T =  3221 K  m_ubv_B = 10.93
# M =   3.148 Msun  T =  6970 K  m_ubv_B = 0.22
# M =  10.204 Msun  T = 27345 K  m_ubv_B = -2.24
# Starting filter: ubv,I   Elapsed time: 2.87 seconds
# Starting synthetic photometry
# M =   0.100 Msun  T =  3221 K  m_ubv_I = 6.71
# M =   3.148 Msun  T =  6970 K  m_ubv_I = -0.51
# M =  10.204 Msun  T = 27345 K  m_ubv_I = -1.64
# Starting filter: ubv,R   Elapsed time: 5.56 seconds
# Starting synthetic photometry
# M =   0.100 Msun  T =  3221 K  m_ubv_R = 8.50
# M =   3.148 Msun  T =  6970 K  m_ubv_R = -0.27
# M =  10.204 Msun  T = 27345 K  m_ubv_R = -1.88
# Starting filter: ubv,U   Elapsed time: 8.28 seconds
# Starting synthetic photometry
# M =   0.100 Msun  T =  3221 K  m_ubv_U = 11.88
# M =   3.148 Msun  T =  6970 K  m_ubv_U = 0.25
# M =  10.204 Msun  T = 27345 K  m_ubv_U = -3.18
# Starting filter: ubv,V   Elapsed time: 11.31 seconds
# Starting synthetic photometry
# M =   0.100 Msun  T =  3221 K  m_ubv_V = 9.44
# M =   3.148 Msun  T =  6970 K  m_ubv_V = -0.09
# M =  10.204 Msun  T = 27345 K  m_ubv_V = -1.98
# Starting filter: ukirt,H   Elapsed time: 14.20 seconds
# Starting synthetic photometry
# M =   0.100 Msun  T =  3221 K  m_ukirt_H = 4.96
# M =   3.148 Msun  T =  6970 K  m_ukirt_H = -0.90
# M =  10.204 Msun  T = 27345 K  m_ukirt_H = -1.26
# Starting filter: ukirt,J   Elapsed time: 16.56 seconds
# Starting synthetic photometry
# M =   0.100 Msun  T =  3221 K  m_ukirt_J = 5.57
# M =   3.148 Msun  T =  6970 K  m_ukirt_J = -0.74
# M =  10.204 Msun  T = 27345 K  m_ukirt_J = -1.36
# Starting filter: ukirt,K   Elapsed time: 18.23 seconds
# Starting synthetic photometry
# M =   0.100 Msun  T =  3221 K  m_ukirt_K = 4.67
# M =   3.148 Msun  T =  6970 K  m_ukirt_K = -0.92
# M =  10.204 Msun  T = 27345 K  m_ukirt_K = -1.16
#       Time taken: 20.59 seconds
# Keep low mass stars below grid and compact objects
# Found 25 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 29 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 43 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 23 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 18 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 30 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 30 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 35 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 10 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 26 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 22 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 17 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 9 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 26 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 19 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Keep low mass stars below grid and compact objects
# Found 15 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 11 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 17 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 37 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 21 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 23 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 20 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 27 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 17 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 25 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 30 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 25 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 31 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 13 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 22 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 27 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 35 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 22 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 21 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 33 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 14 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 21 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 19 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 30 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 29 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 29 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 26 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 15 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 38 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 23 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 23 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 19 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 27 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 20 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 41 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 22 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 2 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 7 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 32 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 27 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 28 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 19 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 19 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 33 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 40 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 15 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 23 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 28 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 23 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 58 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 21 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 19 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 38 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 21 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 30 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 61 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 21 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 22 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 27 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 37 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 34 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 35 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 27 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 30 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 47 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 63 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 19 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 13 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 105 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 19 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 12 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 98 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 23 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 20 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 76 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 21 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 25 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 19 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 104 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 23 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 23 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 37 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 38 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 97 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 81 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 46 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 8 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 16 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 179 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 26 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 19 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 30 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 164 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 31 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 38 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 217 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 33 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 35 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 229 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 61 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 18 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 9 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 43 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 308 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 70 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 22 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 17 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 40 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 202 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 59 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 17 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 17 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 58 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 271 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 20 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 82 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 19 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 23 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 54 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 323 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 82 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 24 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 99 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 201 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 459 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 107 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 18 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 19 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 93 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 351 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 102 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 36 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 12 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 123 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 208 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 548 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 55 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 106 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 29 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 15 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 90 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 563 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 139 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 27 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 22 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 159 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 527 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 78 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 135 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 19 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 21 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 139 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 686 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 176 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 36 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 20 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 9 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 188 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 722 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 189 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 30 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 31 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 200 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 942 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 1 stars out of mass range
# Found 152 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 192 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 27 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 34 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 35 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 30 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 33 companions out of stellar mass range
#  920586 - Evolving test set from population 5 to estimate average initial->final mass ratio
# Keep low mass stars below grid and compact objects
# Found 12 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 12 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 116 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 132 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 53 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 25 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 30 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 156 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 65 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 14 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 55 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 231 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 66 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 41 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 24 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 30 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 340 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 42 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 100 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# ...
#  4027347 - # Done
# Keep low mass stars below grid and compact objects
# Found 25 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 24 companions out of stellar mass range
# # Population 1;  halo -----------------------------------------------------
#  4027970 - # From density profile (number density)
#  4027973 - expected_total_iMass = 0.0247
#  4027975 - expected_total_eMass = 0.0122
#  4027977 - average_iMass_per_star = 0.5739
#  4027979 - mass_loss_correction = 0.4934
#  4027981 - n_expected_stars = 0.0431
#  4027986 - # Determine velocities when position are generated
#  4027991 - # From Generated Field:
#  4027993 - generated_stars = 0
#  4027995 - # Done
#
#
# # Population 2;  nsd ------------------------------------------------------
#  4030013 - # From density profile (number density)
#  4030015 - expected_total_iMass = 0.1483
#  4030017 - expected_total_eMass = 0.0783
#  4030019 - average_iMass_per_star = 0.5739
#  4030021 - mass_loss_correction = 0.5276
#  4030023 - n_expected_stars = 0.2585
#  4030028 - # Determine velocities when position are generated
#  4030034 - # From Generated Field:
#  4030036 - generated_stars = 0
#  4030037 - # Done
#
#
# # Population 3;  thick_disk -----------------------------------------------
#  4030728 - # From density profile (number density)
#  4030730 - expected_total_iMass = 0.2094
#  4030732 - expected_total_eMass = 0.1070
#  4030735 - average_iMass_per_star = 0.5739
#  4030736 - mass_loss_correction = 0.5111
#  4030738 - n_expected_stars = 0.3648
#  4030744 - # Determine velocities when position are generated
#  4030749 - # From Generated Field:
#  4030751 - generated_stars = 0
#  4030753 - # Done
#
#
# # Population 4;  thin_disk_1 ----------------------------------------------
#  4031443 - # From density profile (number density)
#  4031446 - expected_total_iMass = 0.0027
#  4031448 - expected_total_eMass = 0.0017
#  4031450 - average_iMass_per_star = 0.5739
#  4031452 - mass_loss_correction = 0.6188
#  4031454 - n_expected_stars = 0.0048
#  4031459 - # Determine velocities when position are generated
#  4031465 - # From Generated Field:
#  4031467 - generated_stars = 0
#  4031469 - # Done
#
#
# # Population 5;  thin_disk_2 ----------------------------------------------
#  4032126 - # From density profile (number density)
#  4032129 - expected_total_iMass = 0.0484
#  4032131 - expected_total_eMass = 0.0287
#  4032133 - average_iMass_per_star = 0.5739
#  4032135 - mass_loss_correction = 0.5937
#  4032137 - n_expected_stars = 0.0843
#  4032142 - # Determine velocities when position are generated
#  4032148 - # From Generated Field:
#  4032150 - generated_stars = 0
#  4032152 - # Done
#
#
# # Population 6;  thin_disk_3 ----------------------------------------------
#  4032943 - # From density profile (number density)
#  4032946 - expected_total_iMass = 0.1233
#  4032947 - expected_total_eMass = 0.0722
#  4032949 - average_iMass_per_star = 0.5739
#  4032951 - mass_loss_correction = 0.5854
#  4032953 - n_expected_stars = 0.2148
#  4032958 - # Determine velocities when position are generated
#  4032963 - # From Generated Field:
#  4032965 - generated_stars = 0
#  4032967 - # Done
#
#
# # Population 7;  thin_disk_4 ----------------------------------------------
#  4033677 - # From density profile (number density)
#  4033680 - expected_total_iMass = 0.1810
#  4033682 - expected_total_eMass = 0.1014
#  4033684 - average_iMass_per_star = 0.5739
#  4033686 - mass_loss_correction = 0.5600
#  4033688 - n_expected_stars = 0.3154
#  4033694 - # Determine velocities when position are generated
#  4033699 - # From Generated Field:
#  4033702 - generated_stars = 0
#  4033705 - # Done
#
#
# # Population 8;  thin_disk_5 ----------------------------------------------
#  4034388 - # From density profile (number density)
#  4034390 - expected_total_iMass = 0.5038
#  4034393 - expected_total_eMass = 0.2713
#  4034394 - average_iMass_per_star = 0.5739
#  4034397 - mass_loss_correction = 0.5385
#  4034399 - n_expected_stars = 0.8780
#  4034404 - # Determine velocities when position are generated
#  4034409 - # From Generated Field:
#  4034411 - generated_stars = 0
#  4034413 - # Done
#
#
# # Population 9;  thin_disk_6 ----------------------------------------------
#  4035085 - # From density profile (number density)
#  4035089 - expected_total_iMass = 0.6721
#  4035091 - expected_total_eMass = 0.3517
#  4035093 - average_iMass_per_star = 0.5739
#  4035095 - mass_loss_correction = 0.5233
#  4035097 - n_expected_stars = 1.1712
#  4035103 - # Determine velocities when position are generated
#  4035320 - # From Generated Field:
#  4035322 - generated_stars = 3
#  4035325 - generated_total_iMass = 0.6482
#  4035336 - generated_total_eMass = 0.6482
#  4035339 - det_mass_loss_corr = 1.0000
#  4035343 - # Done
# Keep low mass stars below grid and compact objects
# Found 28 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 19 companions out of stellar mass range
# # Population 10;  thin_disk_7 ---------------------------------------------
#  4036051 - # From density profile (number density)
#  4036053 - expected_total_iMass = 1.3861
#  4036055 - expected_total_eMass = 0.7302
#  4036058 - average_iMass_per_star = 0.5739
#  4036060 - mass_loss_correction = 0.5268
#  4036062 - n_expected_stars = 2.4154
#  4036068 - # Determine velocities when position are generated
#  4036184 - # From Generated Field:
#  4036186 - generated_stars = 1
#  4036189 - generated_total_iMass = 0.3911
#  4036200 - generated_total_eMass = 0.3911
#  4036203 - det_mass_loss_corr = 1.0000
#  4036207 - # Done
#
#
# ########################### Combine Populations ###########################
#  4036212 - Number of star systems generated: 32 (35 columns)
#  4036215 - included_columns = ['log_R', 'm_ubv_R', 'log_Teff', 'm_ubv_V', 'm_ukirt_J', 'm_ubv_I', 'm_ubv_B', 'm_ubv_U', 'log_g', 'phase', 'log_L', 'm_ukirt_H', 'm_ukirt_K', 'iMass', 'Mass', 'age', 'Fe/H_initial', 'system_idx', 'n_companions', 'system_Mass', 'x', 'y', 'z', 'Dist', 'l', 'b', 'vr_bc', 'mul', 'mub', 'U', 'V', 'W', 'VR_LSR', 'A_Ks', 'pop']
#  4036217 - Beginning PopSyCLE postprocessing.
#  4036220 - Unused columns dropped
#  4036226 - E(B-V) calculated
#  4036230 - Basic columns renamed
#  4036233 - Age units converted
#  4036239 - Galactic longitude wrapped
#  4036243 - Added mbol via eval
#  4036246 - Added systemMass via eval
#  4036252 - Renamed mag cols
#  4036255 - Multiplicity and remnant columns added
#  4036257 - PopSyCLE system_df modifications complete - binning and saving file
#  4036269 - ---------------------------------------------------------------
#
#
#
# ############################# Update location #############################
#  4036279 - # set location to:
#  4036281 - l, b = (1.15 deg, -1.05 deg)
#  4036284 - # set field scale to:
#  4036286 - field_scale = 2.076e-04 deg
# Keep low mass stars below grid and compact objects
# Found 24 companions out of stellar mass range
# Index(['log_R', 'Bessell_R', 'log_Teff', 'Bessell_V', 'UKIDSS_J', 'Bessell_I',
#        'Bessell_B', 'Bessell_U', 'log_g', 'phase', 'log_L', 'UKIDSS_H',
#        'UKIDSS_K', 'iMass', 'Mass', 'age', 'Fe/H_initial', 'system_idx',
#        'n_companions', 'system_Mass', 'x', 'y', 'z', 'Dist', 'l', 'b', 'vr_bc',
#        'mul', 'mub', 'U', 'V', 'W', 'VR_LSR', 'A_Ks', 'pop'],
#       dtype='object')
# ############################# Generate Field ##############################
#
#
# # Population 0;  bulge ----------------------------------------------------
#  4039553 - # From density profile (number density)
#  4039556 - expected_total_iMass = 18.5886
#  4039587 - expected_total_eMass = 9.7416
#  4039589 - average_iMass_per_star = 0.5739
#  4039591 - mass_loss_correction = 0.5241
#  4039593 - n_expected_stars = 32.3919
#  4039598 - # Determine velocities when position are generated
# Keep low mass stars below grid and compact objects
# Found 34 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 34 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 16 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 41 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 19 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 17 companions out of stellar mass range
#  4040182 - # From Generated Field:
#  4040184 - generated_stars = 36
#  4040186 - generated_total_iMass = 49.7785
#  4040197 - generated_total_eMass = 10.6914
#  4040199 - det_mass_loss_corr = 0.2148
#  4040204 - # Done
# Keep low mass stars below grid and compact objects
# Found 34 companions out of stellar mass range
# # Population 1;  halo -----------------------------------------------------
#  4040846 - # From density profile (number density)
#  4040853 - expected_total_iMass = 0.0247
#  4040857 - expected_total_eMass = 0.0122
#  4040861 - average_iMass_per_star = 0.5739
#  4040865 - mass_loss_correction = 0.4934
#  4040868 - n_expected_stars = 0.0431
#  4040879 - # Determine velocities when position are generated
#  4040890 - # From Generated Field:
#  4040895 - generated_stars = 0
#  4040899 - # Done
#
#
# # Population 2;  nsd ------------------------------------------------------
#  4042845 - # From density profile (number density)
#  4042848 - expected_total_iMass = 0.1622
#  4042851 - expected_total_eMass = 0.0856
#  4042853 - average_iMass_per_star = 0.5739
#  4042855 - mass_loss_correction = 0.5276
#  4042857 - n_expected_stars = 0.2826
#  4042862 - # Determine velocities when position are generated
#  4042966 - # From Generated Field:
#  4042969 - generated_stars = 1
#  4042971 - generated_total_iMass = 0.2538
#  4042981 - generated_total_eMass = 0.2538
#  4042983 - det_mass_loss_corr = 1.0000
#  4042988 - # Done
#
#
# # Population 3;  thick_disk -----------------------------------------------
# Keep low mass stars below grid and compact objects
# Found 31 companions out of stellar mass range
#  4043720 - # From density profile (number density)
#  4043723 - expected_total_iMass = 0.2103
#  4043726 - expected_total_eMass = 0.1075
#  4043728 - average_iMass_per_star = 0.5739
#  4043730 - mass_loss_correction = 0.5111
#  4043733 - n_expected_stars = 0.3664
#  4043739 - # Determine velocities when position are generated
#  4043745 - # From Generated Field:
#  4043748 - generated_stars = 0
#  4043750 - # Done
#
#
# # Population 4;  thin_disk_1 ----------------------------------------------
#  4044477 - # From density profile (number density)
#  4044481 - expected_total_iMass = 0.0029
#  4044483 - expected_total_eMass = 0.0018
#  4044486 - average_iMass_per_star = 0.5739
#  4044488 - mass_loss_correction = 0.6188
#  4044490 - n_expected_stars = 0.0050
#  4044495 - # Determine velocities when position are generated
#  4044501 - # From Generated Field:
#  4044503 - generated_stars = 0
#  4044505 - # Done
#
#
# # Population 5;  thin_disk_2 ----------------------------------------------
#  4045129 - # From density profile (number density)
#  4045135 - expected_total_iMass = 0.0508
#  4045137 - expected_total_eMass = 0.0302
#  4045139 - average_iMass_per_star = 0.5739
#  4045142 - mass_loss_correction = 0.5937
#  4045144 - n_expected_stars = 0.0886
#  4045154 - # Determine velocities when position are generated
#  4045267 - # From Generated Field:
#  4045270 - generated_stars = 1
#  4045273 - generated_total_iMass = 0.2482
#  4045283 - generated_total_eMass = 0.2482
#  4045288 - det_mass_loss_corr = 1.0000
#  4045295 - # Done
#
#
# # Population 6;  thin_disk_3 ----------------------------------------------
# Keep low mass stars below grid and compact objects
# Found 18 companions out of stellar mass range
#  4046052 - # From density profile (number density)
#  4046055 - expected_total_iMass = 0.1279
#  4046058 - expected_total_eMass = 0.0749
#  4046060 - average_iMass_per_star = 0.5739
#  4046063 - mass_loss_correction = 0.5854
#  4046065 - n_expected_stars = 0.2228
#  4046072 - # Determine velocities when position are generated
#  4046080 - # From Generated Field:
#  4046085 - generated_stars = 0
#  4046088 - # Done
#
#
# # Population 7;  thin_disk_4 ----------------------------------------------
#  4046741 - # From density profile (number density)
#  4046746 - expected_total_iMass = 0.1860
#  4046748 - expected_total_eMass = 0.1042
#  4046751 - average_iMass_per_star = 0.5739
#  4046753 - mass_loss_correction = 0.5600
#  4046756 - n_expected_stars = 0.3241
#  4046762 - # Determine velocities when position are generated
#  4046769 - # From Generated Field:
#  4046771 - generated_stars = 0
#  4046774 - # Done
#
#
# # Population 8;  thin_disk_5 ----------------------------------------------
#  4047464 - # From density profile (number density)
#  4047467 - expected_total_iMass = 0.5139
#  4047469 - expected_total_eMass = 0.2767
#  4047471 - average_iMass_per_star = 0.5739
#  4047474 - mass_loss_correction = 0.5385
#  4047476 - n_expected_stars = 0.8954
#  4047483 - # Determine velocities when position are generated
#  4047597 - # From Generated Field:
#  4047600 - generated_stars = 1
#  4047603 - generated_total_iMass = 0.3122
#  4047614 - generated_total_eMass = 0.3122
#  4047617 - det_mass_loss_corr = 1.0000
#  4047622 - # Done
#
#
# # Population 9;  thin_disk_6 ----------------------------------------------
# Keep low mass stars below grid and compact objects
# Found 21 companions out of stellar mass range
#  4048452 - # From density profile (number density)
#  4048455 - expected_total_iMass = 0.6825
#  4048458 - expected_total_eMass = 0.3572
#  4048460 - average_iMass_per_star = 0.5739
#  4048463 - mass_loss_correction = 0.5233
#  4048466 - n_expected_stars = 1.1892
#  4048471 - # Determine velocities when position are generated
#  4048584 - # From Generated Field:
#  4048586 - generated_stars = 1
#  4048588 - generated_total_iMass = 0.4284
#  4048600 - generated_total_eMass = 0.4284
#  4048602 - det_mass_loss_corr = 1.0000
#  4048606 - # Done
#
#
# # Population 10;  thin_disk_7 ---------------------------------------------
# Keep low mass stars below grid and compact objects
# Found 28 companions out of stellar mass range
#  4049246 - # From density profile (number density)
#  4049248 - expected_total_iMass = 1.4070
#  4049250 - expected_total_eMass = 0.7412
#  4049252 - average_iMass_per_star = 0.5739
#  4049254 - mass_loss_correction = 0.5268
#  4049256 - n_expected_stars = 2.4519
#  4049263 - # Determine velocities when position are generated
#  4049438 - # From Generated Field:
#  4049441 - generated_stars = 3
#  4049443 - generated_total_iMass = 0.9760
#  4049455 - generated_total_eMass = 0.9760
#  4049458 - det_mass_loss_corr = 1.0000
#  4049463 - # Done
#
#
# ########################### Combine Populations ###########################
#  4049470 - Number of star systems generated: 43 (35 columns)
#  4049473 - included_columns = ['log_R', 'm_ubv_R', 'log_Teff', 'm_ubv_V', 'm_ukirt_J', 'm_ubv_I', 'm_ubv_B', 'm_ubv_U', 'log_g', 'phase', 'log_L', 'm_ukirt_H', 'm_ukirt_K', 'iMass', 'Mass', 'age', 'Fe/H_initial', 'system_idx', 'n_companions', 'system_Mass', 'x', 'y', 'z', 'Dist', 'l', 'b', 'vr_bc', 'mul', 'mub', 'U', 'V', 'W', 'VR_LSR', 'A_Ks', 'pop']
#  4049475 - Beginning PopSyCLE postprocessing.
#  4049479 - Unused columns dropped
#  4049486 - E(B-V) calculated
#  4049489 - Basic columns renamed
#  4049493 - Age units converted
#  4049497 - Galactic longitude wrapped
#  4049501 - Added mbol via eval
#  4049504 - Added systemMass via eval
#  4049509 - Renamed mag cols
#  4049512 - Multiplicity and remnant columns added
#  4049514 - PopSyCLE system_df modifications complete - binning and saving file
#  4049527 - ---------------------------------------------------------------
# Keep low mass stars below grid and compact objects
# Found 32 companions out of stellar mass range
# Keep low mass stars below grid and compact objects
# Found 28 companions out of stellar mass range
# Index(['log_R', 'Bessell_R', 'log_Teff', 'Bessell_V', 'UKIDSS_J', 'Bessell_I',
#        'Bessell_B', 'Bessell_U', 'log_g', 'phase', 'log_L', 'UKIDSS_H',
#        'UKIDSS_K', 'iMass', 'Mass', 'age', 'Fe/H_initial', 'system_idx',
#        'n_companions', 'system_Mass', 'x', 'y', 'z', 'Dist', 'l', 'b', 'vr_bc',
#        'mul', 'mub', 'U', 'V', 'W', 'VR_LSR', 'A_Ks', 'pop'],
#       dtype='object')
#  4076437 - PopSyCLE formatted output saved in synthpop_output/synthpopsycle_SPISEA_l1.000_b-1.200_psc.h5

# %%
synthetic.calc_events(hdf5_file = "synthpop_output/synthpopsycle_SPISEA_l1.000_b-1.200_psc.h5", 
                      hdf5_file_comp = "synthpop_output/synthpopsycle_SPISEA_l1.000_b-1.200_psc_companions.h5", 
                      output_root2 = "synthpop_output/synthpopsycle_SPISEA_l1.000_b-1.200_psc",  
                      radius_cut = 2, obs_time = 1000,  n_obs = 11,  
                      theta_frac = 2,  blend_rad = 0.65,  overwrite = True,  n_proc = 4)
# Out:
# Working on loop ll, bb =  1 0
# Working on loop ll, bb =  1 1
# Working on loop ll, bb =  1 2
# Working on loop ll, bb =  1 3
# Working on loop ll, bb =  1 4
# Working on loop ll, bb =  1 5
# Working on loop ll, bb =  1 6
# Working on loop ll, bb =  1 7
# Working on loop ll, bb =  1 8
# Working on loop ll, bb =  1 9
# Working on loop ll, bb =  1 10
# Working on loop ll, bb =  1 11
# Working on loop ll, bb =  1 12
# Working on loop ll, bb =  1 13
# Working on loop ll, bb =  1 14
# Working on loop ll, bb =  5 0
# Working on loop ll, bb =  5 1
# Working on loop ll, bb =  5 2
# Working on loop ll, bb =  5 3
# Working on loop ll, bb =  5 4
# Working on loop ll, bb =  5 5
# Working on loop ll, bb =  5 6
# Working on loop ll, bb =  5 7
# Working on loop ll, bb =  5 8
# Working on loop ll, bb =  5 9
# Working on loop ll, bb =  5 10
# Working on loop ll, bb =  5 11
# Working on loop ll, bb =  5 12
# Working on loop ll, bb =  5 13
# Working on loop ll, bb =  5 14
# Working on loop ll, bb =  9 0
# Working on loop ll, bb =  9 1
# Working on loop ll, bb =  9 2
# Working on loop ll, bb =  9 3
# Working on loop ll, bb =  9 4
# Working on loop ll, bb =  9 5
# Working on loop ll, bb =  9 6
# Working on loop ll, bb =  9 7
# Working on loop ll, bb =  9 8
# Working on loop ll, bb =  9 9
# Working on loop ll, bb =  9 10
# Working on loop ll, bb =  9 11
# Working on loop ll, bb =  9 12
# Working on loop ll, bb =  9 13
# Working on loop ll, bb =  9 14
# Working on loop ll, bb =  0 0
# Working on loop ll, bb =  0 1
# Working on loop ll, bb =  0 2
# Working on loop ll, bb =  0 3
# Working on loop ll, bb =  0 4
# Working on loop ll, bb =  0 5
# Working on loop ll, bb =  0 6
# Working on loop ll, bb =  0 7
# Working on loop ll, bb =  0 8
# Working on loop ll, bb =  0 9
# Working on loop ll, bb =  0 10
# Working on loop ll, bb =  0 11
# Working on loop ll, bb =  0 12
# Working on loop ll, bb =  0 13
# Working on loop ll, bb =  0 14
# Working on loop ll, bb =  4 0
# Working on loop ll, bb =  4 1
# Working on loop ll, bb =  4 2
# Working on loop ll, bb =  4 3
# Working on loop ll, bb =  4 4
# Working on loop ll, bb =  4 5
# Working on loop ll, bb =  4 6
# Working on loop ll, bb =  4 7
# Working on loop ll, bb =  4 8
# Working on loop ll, bb =  4 9
# Working on loop ll, bb =  4 10
# Working on loop ll, bb =  4 11
# Working on loop ll, bb =  4 12
# Working on loop ll, bb =  4 13
# Working on loop ll, bb =  4 14
# Working on loop ll, bb =  8 0
# Working on loop ll, bb =  8 1
# Working on loop ll, bb =  8 2
# Working on loop ll, bb =  8 3
# Working on loop ll, bb =  8 4
# Working on loop ll, bb =  8 5
# Working on loop ll, bb =  8 6
# Working on loop ll, bb =  8 7
# Working on loop ll, bb =  8 8
# Working on loop ll, bb =  8 9
# Working on loop ll, bb =  8 10
# Working on loop ll, bb =  8 11
# Working on loop ll, bb =  8 12
# Working on loop ll, bb =  8 13
# Working on loop ll, bb =  8 14
# Working on loop ll, bb =  12 0
# Working on loop ll, bb =  12 1
# Working on loop ll, bb =  12 2
# Working on loop ll, bb =  12 3
# Working on loop ll, bb =  12 4
# Working on loop ll, bb =  12 5
# Working on loop ll, bb =  12 6
# Working on loop ll, bb =  12 7
# Working on loop ll, bb =  12 8
# Working on loop ll, bb =  12 9
# Working on loop ll, bb =  12 10
# Working on loop ll, bb =  12 11
# Working on loop ll, bb =  12 12
# Working on loop ll, bb =  12 13
# Working on loop ll, bb =  12 14
# Working on loop ll, bb =  3 0
# Working on loop ll, bb =  3 1
# Working on loop ll, bb =  3 2
# Working on loop ll, bb =  3 3
# Working on loop ll, bb =  3 4
# Working on loop ll, bb =  3 5
# Working on loop ll, bb =  3 6
# Working on loop ll, bb =  3 7
# Working on loop ll, bb =  3 8
# Working on loop ll, bb =  3 9
# Working on loop ll, bb =  3 10
# Working on loop ll, bb =  3 11
# Working on loop ll, bb =  3 12
# Working on loop ll, bb =  3 13
# Working on loop ll, bb =  3 14
# Working on loop ll, bb =  6 0
# Working on loop ll, bb =  6 1
# Working on loop ll, bb =  6 2
# Working on loop ll, bb =  6 3
# Working on loop ll, bb =  6 4
# Working on loop ll, bb =  6 5
# Working on loop ll, bb =  6 6
# Working on loop ll, bb =  6 7
# Working on loop ll, bb =  6 8
# Working on loop ll, bb =  6 9
# Working on loop ll, bb =  6 10
# Working on loop ll, bb =  6 11
# Working on loop ll, bb =  6 12
# Working on loop ll, bb =  6 13
# Working on loop ll, bb =  6 14
# Working on loop ll, bb =  10 0
# Working on loop ll, bb =  10 1
# Working on loop ll, bb =  10 2
# Working on loop ll, bb =  10 3
# Working on loop ll, bb =  10 4
# Working on loop ll, bb =  10 5
# Working on loop ll, bb =  10 6
# Working on loop ll, bb =  10 7
# Working on loop ll, bb =  10 8
# Working on loop ll, bb =  10 9
# Working on loop ll, bb =  10 10
# Working on loop ll, bb =  10 11
# Working on loop ll, bb =  10 12
# Working on loop ll, bb =  10 13
# Working on loop ll, bb =  10 14
# Working on loop ll, bb =  14 0
# Working on loop ll, bb =  14 1
# Working on loop ll, bb =  14 2
# Working on loop ll, bb =  14 3
# Working on loop ll, bb =  14 4
# Working on loop ll, bb =  14 5
# Working on loop ll, bb =  14 6
# Working on loop ll, bb =  14 7
# Working on loop ll, bb =  14 8
# Working on loop ll, bb =  14 9
# Working on loop ll, bb =  14 10
# Working on loop ll, bb =  14 11
# Working on loop ll, bb =  14 12
# Working on loop ll, bb =  14 13
# Working on loop ll, bb =  14 14
# Working on loop ll, bb =  2 0
# Working on loop ll, bb =  2 1
# Working on loop ll, bb =  2 2
# Working on loop ll, bb =  2 3
# Working on loop ll, bb =  2 4
# Working on loop ll, bb =  2 5
# Working on loop ll, bb =  2 6
# Working on loop ll, bb =  2 7
# Working on loop ll, bb =  2 8
# Working on loop ll, bb =  2 9
# Working on loop ll, bb =  2 10
# Working on loop ll, bb =  2 11
# Working on loop ll, bb =  2 12
# Working on loop ll, bb =  2 13
# Working on loop ll, bb =  2 14
# Working on loop ll, bb =  7 0
# Working on loop ll, bb =  7 1
# Working on loop ll, bb =  7 2
# Working on loop ll, bb =  7 3
# Working on loop ll, bb =  7 4
# Working on loop ll, bb =  7 5
# Working on loop ll, bb =  7 6
# Working on loop ll, bb =  7 7
# Working on loop ll, bb =  7 8
# Working on loop ll, bb =  7 9
# Working on loop ll, bb =  7 10
# Working on loop ll, bb =  7 11
# Working on loop ll, bb =  7 12
# Working on loop ll, bb =  7 13
# Working on loop ll, bb =  7 14
# Working on loop ll, bb =  11 0
# Working on loop ll, bb =  11 1
# Working on loop ll, bb =  11 2
# Working on loop ll, bb =  11 3
# Working on loop ll, bb =  11 4
# Working on loop ll, bb =  11 5
# Working on loop ll, bb =  11 6
# Working on loop ll, bb =  11 7
# Working on loop ll, bb =  11 8
# Working on loop ll, bb =  11 9
# Working on loop ll, bb =  11 10
# Working on loop ll, bb =  11 11
# Working on loop ll, bb =  11 12
# Working on loop ll, bb =  11 13
# Working on loop ll, bb =  11 14
# Working on loop ll, bb =  13 0
# Working on loop ll, bb =  13 1
# Working on loop ll, bb =  13 2
# Working on loop ll, bb =  13 3
# Working on loop ll, bb =  13 4
# Working on loop ll, bb =  13 5
# Working on loop ll, bb =  13 6
# Working on loop ll, bb =  13 7
# Working on loop ll, bb =  13 8
# Working on loop ll, bb =  13 9
# Working on loop ll, bb =  13 10
# Working on loop ll, bb =  13 11
# Working on loop ll, bb =  13 12
# Working on loop ll, bb =  13 13
# Working on loop ll, bb =  13 14
# Candidate events detected:  24
# calc_events runtime : 13.426582 s

# %%
synthetic.refine_events(input_root = 'synthpop_output/synthpopsycle_SPISEA_l1.000_b-1.200_psc',
                        hdf5_file_comp = 'synthpop_output/synthpopsycle_SPISEA_l1.000_b-1.200_psc_companions.h5',
                        filter_dict={'ubv':['I']},
                        red_law = 'Damineli16', 
                        overwrite = True, 
                        output_file = 'default',
                        galactic_model_code = 'synthpop')
# Out:
# <TableColumns names=('ubv_R_L','teff_L','ubv_V_L','ubv_J_L','ubv_I_L','ubv_B_L','ubv_U_L','grav_L','ubv_H_L','ubv_K_L','zams_mass_L','mass_L','age_L','obj_id_L','N_companions_L','px_L','py_L','pz_L','rad_L','glon_L','glat_L','vr_L','mu_lcosb_L','mu_b_L','vx_L','vy_L','vz_L','popid_L','isMultiple_L','exbv_L','mbol_L','systemMass_L','rem_id_L','sep_L','ubv_R_S','teff_S','ubv_V_S','ubv_J_S','ubv_I_S','ubv_B_S','ubv_U_S','grav_S','ubv_H_S','ubv_K_S','zams_mass_S','mass_S','age_S','obj_id_S','N_companions_S','px_S','py_S','pz_S','rad_S','glon_S','glat_S','vr_S','mu_lcosb_S','mu_b_S','vx_S','vy_S','vz_S','popid_S','isMultiple_S','exbv_S','mbol_S','systemMass_S','rem_id_S','sep_S','theta_E','u0','mu_rel','t0')>
# Original candidate events:  20
# Candidate events in survey window:  6
# On square l0b0
# On square l0b1
# On square l0b10
# On square l0b11
# On square l0b12
# On square l0b13
# On square l0b14
# On square l0b15
# On square l0b2
# On square l0b3
# On square l0b4
# On square l0b5
# On square l0b6
# On square l0b7
# On square l0b8
# On square l0b9
# On square l10b0
# On square l10b1
# On square l10b10
# On square l10b11
# On square l10b12
# On square l10b13
# On square l10b14
# On square l10b15
# On square l10b2
# On square l10b3
# On square l10b4
# On square l10b5
# On square l10b6
# On square l10b7
# On square l10b8
# On square l10b9
# On square l11b0
# On square l11b1
# On square l11b10
# On square l11b11
# On square l11b12
# On square l11b13
# On square l11b14
# On square l11b15
# On square l11b2
# On square l11b3
# On square l11b4
# On square l11b5
# On square l11b6
# On square l11b7
# On square l11b8
# On square l11b9
# On square l12b0
# On square l12b1
# On square l12b10
# On square l12b11
# On square l12b12
# On square l12b13
# On square l12b14
# On square l12b15
# On square l12b2
# On square l12b3
# On square l12b4
# On square l12b5
# On square l12b6
# On square l12b7
# On square l12b8
# On square l12b9
# On square l13b0
# On square l13b1
# On square l13b10
# On square l13b11
# On square l13b12
# On square l13b13
# On square l13b14
# On square l13b15
# On square l13b2
# On square l13b3
# On square l13b4
# On square l13b5
# On square l13b6
# On square l13b7
# On square l13b8
# On square l13b9
# On square l14b0
# On square l14b1
# On square l14b10
# On square l14b11
# On square l14b12
# On square l14b13
# On square l14b14
# On square l14b15
# On square l14b2
# On square l14b3
# On square l14b4
# On square l14b5
# On square l14b6
# On square l14b7
# On square l14b8
# On square l14b9
# On square l15b0
# On square l15b1
# On square l15b10
# On square l15b11
# On square l15b12
# On square l15b13
# On square l15b14
# On square l15b15
# On square l15b2
# On square l15b3
# On square l15b4
# On square l15b5
# On square l15b6
# On square l15b7
# On square l15b8
# On square l15b9
# On square l1b0
# On square l1b1
# On square l1b10
# On square l1b11
# On square l1b12
# On square l1b13
# On square l1b14
# On square l1b15
# On square l1b2
# On square l1b3
# On square l1b4
# On square l1b5
# On square l1b6
# On square l1b7
# On square l1b8
# On square l1b9
# On square l2b0
# On square l2b1
# On square l2b10
# On square l2b11
# On square l2b12
# On square l2b13
# On square l2b14
# On square l2b15
# On square l2b2
# On square l2b3
# On square l2b4
# On square l2b5
# On square l2b6
# On square l2b7
# On square l2b8
# On square l2b9
# On square l3b0
# On square l3b1
# On square l3b10
# On square l3b11
# On square l3b12
# On square l3b13
# On square l3b14
# On square l3b15
# On square l3b2
# On square l3b3
# On square l3b4
# On square l3b5
# On square l3b6
# On square l3b7
# On square l3b8
# On square l3b9
# On square l4b0
# On square l4b1
# On square l4b10
# On square l4b11
# On square l4b12
# On square l4b13
# On square l4b14
# On square l4b15
# On square l4b2
# On square l4b3
# On square l4b4
# On square l4b5
# On square l4b6
# On square l4b7
# On square l4b8
# On square l4b9
# On square l5b0
# On square l5b1
# On square l5b10
# On square l5b11
# On square l5b12
# On square l5b13
# On square l5b14
# On square l5b15
# On square l5b2
# On square l5b3
# On square l5b4
# On square l5b5
# On square l5b6
# On square l5b7
# On square l5b8
# On square l5b9
# On square l6b0
# On square l6b1
# On square l6b10
# On square l6b11
# On square l6b12
# On square l6b13
# On square l6b14
# On square l6b15
# On square l6b2
# On square l6b3
# On square l6b4
# On square l6b5
# On square l6b6
# On square l6b7
# On square l6b8
# On square l6b9
# On square l7b0
# On square l7b1
# On square l7b10
# On square l7b11
# On square l7b12
# On square l7b13
# On square l7b14
# On square l7b15
# On square l7b2
# On square l7b3
# On square l7b4
# On square l7b5
# On square l7b6
# On square l7b7
# On square l7b8
# On square l7b9
# On square l8b0
# On square l8b1
# On square l8b10
# On square l8b11
# On square l8b12
# On square l8b13
# On square l8b14
# On square l8b15
# On square l8b2
# On square l8b3
# On square l8b4
# On square l8b5
# On square l8b6
# On square l8b7
# On square l8b8
# On square l8b9
# On square l9b0
# On square l9b1
# On square l9b10
# On square l9b11
# On square l9b12
# On square l9b13
# On square l9b14
# On square l9b15
# On square l9b2
# On square l9b3
# On square l9b4
# On square l9b5
# On square l9b6
# On square l9b7
# On square l9b8
# On square l9b9
# refine_events runtime : 2.422728 s

# %%
synthetic.refine_binary_events(events="synthpop_output/synthpopsycle_SPISEA_l1.000_b-1.200_psc_refined_events_ubv_I_Damineli16.fits", 
                               companions = "synthpop_output/synthpopsycle_SPISEA_l1.000_b-1.200_psc_refined_events_ubv_I_Damineli16_companions.fits", 
                               filter_name = 'I',
                               photometric_system = 'ubv', 
                               overwrite = True,
                               n_proc=1,
                               output_file = 'default', 
                               save_phot = True, 
                               phot_dir = 'example_bin_phot')
# Out:
# /u/shepbrooke/code/PopSyCLE/popsycle/binary_utils.py:66: RuntimeWarning: divide by zero encountered in log10
#   m_diff = -2.5*np.log10(f1 - f2)
# /opt/mambaforge3/envs/astro-synthpop/lib/python3.11/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "epv00" yielded 5000 of "warning: date outsidethe range 1900-2100 AD"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /u/shepbrooke/code/BAGLE_Microlensing/src/bagle/model.py:2239: UserWarning: Warning: converting a masked element to nan.
#   setattr(self, param, np.array(param_var))
# /opt/mambaforge3/envs/astro-synthpop/lib/python3.11/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "epv00" yielded 5000 of "warning: date outsidethe range 1900-2100 AD"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /u/shepbrooke/code/PopSyCLE/popsycle/binary_utils.py:66: RuntimeWarning: divide by zero encountered in log10
#   m_diff = -2.5*np.log10(f1 - f2)
# /u/shepbrooke/code/BAGLE_Microlensing/src/bagle/model.py:2239: UserWarning: Warning: converting a masked element to nan.
#   setattr(self, param, np.array(param_var))
# /opt/mambaforge3/envs/astro-synthpop/lib/python3.11/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "epv00" yielded 5000 of "warning: date outsidethe range 1900-2100 AD"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /u/shepbrooke/code/BAGLE_Microlensing/src/bagle/model.py:16741: RuntimeWarning: invalid value encountered in divide
#   dwbardz = self.m1 / (z_arr - z1[:, np.newaxis, np.newaxis]) ** 2
# /u/shepbrooke/code/BAGLE_Microlensing/src/bagle/model.py:16742: RuntimeWarning: invalid value encountered in divide
#   dwbardz += self.m2 / (z_arr - z2[:, np.newaxis, np.newaxis]) ** 2
# /u/shepbrooke/code/PopSyCLE/popsycle/binary_utils.py:66: RuntimeWarning: invalid value encountered in log10
#   m_diff = -2.5*np.log10(f1 - f2)
# /u/shepbrooke/code/PopSyCLE/popsycle/binary_utils.py:76: UserWarning: Warning: first magnitude dimmer than second magnitude. Result will be nan.
#   warnings.warn("Warning: first magnitude dimmer than second magnitude. Result will be nan.")
# /u/shepbrooke/code/BAGLE_Microlensing/src/bagle/model.py:15222: UserWarning: Warning: converting a masked element to nan.
#   self.mag_src_sec = np.array(mag_src_sec)
# /u/shepbrooke/code/PopSyCLE/popsycle/synthetic.py:6147: UserWarning: Warning: converting a masked element to nan.
#   if np.isnan(model_parameter_dict['mag_src_sec']) and np.isnan(model_parameter_dict['mag_src_pri']):
# /opt/mambaforge3/envs/astro-synthpop/lib/python3.11/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "epv00" yielded 5000 of "warning: date outsidethe range 1900-2100 AD"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /u/shepbrooke/code/PopSyCLE/popsycle/binary_utils.py:66: RuntimeWarning: invalid value encountered in log10
#   m_diff = -2.5*np.log10(f1 - f2)
# /u/shepbrooke/code/PopSyCLE/popsycle/binary_utils.py:76: UserWarning: Warning: first magnitude dimmer than second magnitude. Result will be nan.
#   warnings.warn("Warning: first magnitude dimmer than second magnitude. Result will be nan.")
# /u/shepbrooke/code/BAGLE_Microlensing/src/bagle/model.py:15222: UserWarning: Warning: converting a masked element to nan.
#   self.mag_src_sec = np.array(mag_src_sec)
# /u/shepbrooke/code/PopSyCLE/popsycle/synthetic.py:6147: UserWarning: Warning: converting a masked element to nan.
#   if np.isnan(model_parameter_dict['mag_src_sec']) and np.isnan(model_parameter_dict['mag_src_pri']):
# /opt/mambaforge3/envs/astro-synthpop/lib/python3.11/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "epv00" yielded 5000 of "warning: date outsidethe range 1900-2100 AD"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /u/shepbrooke/code/PopSyCLE/popsycle/binary_utils.py:66: RuntimeWarning: invalid value encountered in log10
#   m_diff = -2.5*np.log10(f1 - f2)
# /u/shepbrooke/code/PopSyCLE/popsycle/binary_utils.py:76: UserWarning: Warning: first magnitude dimmer than second magnitude. Result will be nan.
#   warnings.warn("Warning: first magnitude dimmer than second magnitude. Result will be nan.")
# /u/shepbrooke/code/BAGLE_Microlensing/src/bagle/model.py:19371: UserWarning: Warning: converting a masked element to nan.
#   self.mag_src_sec = np.array([mag_src_sec])
# /u/shepbrooke/code/PopSyCLE/popsycle/synthetic.py:6147: UserWarning: Warning: converting a masked element to nan.
#   if np.isnan(model_parameter_dict['mag_src_sec']) and np.isnan(model_parameter_dict['mag_src_pri']):
# refine_binary_events runtime : 6.154693 s

# %%
t = Table.read('synthpop_output/synthpopsycle_SPISEA_l1.000_b-1.200_psc_refined_events_ubv_I_Damineli16_rb.fits')
print(t.colnames)

bin = Table.read('synthpop_output/synthpopsycle_SPISEA_l1.000_b-1.200_psc_refined_events_ubv_I_Damineli16_companions_rb.fits')
print(bin.colnames)
# Out:
# ['obj_id_L', 'obj_id_S', 'ubv_R_L', 'teff_L', 'ubv_V_L', 'ubv_J_L', 'ubv_I_L', 'ubv_B_L', 'ubv_U_L', 'grav_L', 'ubv_H_L', 'ubv_K_L', 'zams_mass_L', 'mass_L', 'age_L', 'N_companions_L', 'px_L', 'py_L', 'pz_L', 'rad_L', 'glon_L', 'glat_L', 'vr_L', 'mu_lcosb_L', 'mu_b_L', 'vx_L', 'vy_L', 'vz_L', 'popid_L', 'isMultiple_L', 'exbv_L', 'mbol_L', 'systemMass_L', 'rem_id_L', 'sep_L', 'ubv_R_S', 'teff_S', 'ubv_V_S', 'ubv_J_S', 'ubv_I_S', 'ubv_B_S', 'ubv_U_S', 'grav_S', 'ubv_H_S', 'ubv_K_S', 'zams_mass_S', 'mass_S', 'age_S', 'N_companions_S', 'px_S', 'py_S', 'pz_S', 'rad_S', 'glon_S', 'glat_S', 'vr_S', 'mu_lcosb_S', 'mu_b_S', 'vx_S', 'vy_S', 'vz_S', 'popid_S', 'isMultiple_S', 'exbv_S', 'mbol_S', 'systemMass_S', 'rem_id_S', 'sep_S', 'theta_E', 'u0', 'mu_rel', 't0', 't_E', 'ubv_I_app_S', 'ubv_I_app_L', 'cent_glon_I_N', 'cent_glat_I_N', 'ubv_I_app_N', 'ubv_I_app_LSN', 'delta_m_I', 'f_blend_I', 'pi_rel', 'pi_E', 'pps_seed', 'gal_seed', 'n_peaks', 'bin_delta_m', 'tE_sys', 'tE_primary', 'primary_t', 'avg_t', 'std_t', 'asymmetry', 'companion_idx_list']
# ['system_idx', 'm_ubv_R', 'm_ubv_V', 'm_ubv_J', 'm_ubv_I', 'm_ubv_B', 'm_ubv_U', 'logg', 'phase', 'L', 'm_ubv_H', 'm_ubv_K', 'zams_mass', 'mass', 'e', 'log_a', 'zams_mass_prim', 'i', 'Omega', 'omega', 'glat', 'glon', 'prim_type', 'q', 'sep', 'P', 'obj_id_L', 'obj_id_S', 'alpha', 'phi_pi_E', 'phi', 'tp', 'companion_idx']

# %%
bh_idx = np.where(t['rem_id_L'] == 103)[0]
ns_idx = np.where(t['rem_id_L'] == 102)[0]
wd_idx = np.where(t['rem_id_L'] == 101)[0]
st_idx = np.where(t['rem_id_L'] == 0)[0]
print('Number of BHs: ' + str(len(bh_idx)))
print('Number of NSs: ' + str(len(ns_idx)))
print('Number of WDs: ' + str(len(wd_idx)))
print('Number of stars: ' + str(len(st_idx)))
# Out:
# Number of BHs: 0
# Number of NSs: 0
# Number of WDs: 3
# Number of stars: 3

# %%
plt.hist(t['t_E'], bins = np.logspace(0, 2.5, 15))
plt.xscale('log')
plt.yscale('log')
plt.xlabel('$t_E$ (days)')
# Out:
# Text(0.5, 0, '$t_E$ (days)')

# %%
bh_idx = t[t['rem_id_L'] == 103]
ns_idx = t[t['rem_id_L'] == 102]
wd_idx = t[t['rem_id_L'] == 101]
st_idx = t[t['rem_id_L'] == 0]

plt.hist(bh_idx['t_E'], bins = np.logspace(0, 2.5, 15),histtype=u'step', label="BHs")
plt.hist(ns_idx['t_E'], bins = np.logspace(0, 2.5, 15),histtype=u'step', label="NSs")
plt.hist(wd_idx['t_E'], bins = np.logspace(0, 2.5, 15),histtype=u'step', label="WDs")
plt.hist(st_idx['t_E'], bins = np.logspace(0, 2.5, 15),histtype=u'step', label="Stars")
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.xlabel('$t_E$ (days)')
# Out:
# Text(0.5, 0, '$t_E$ (days)')

# %%
no_companions_lens = t[t['N_companions_L'] == 0]
no_companions_source = t[t['N_companions_S'] == 0]
companions_lens = t[t['N_companions_L'] != 0]
companions_source= t[t['N_companions_S'] != 0]

plt.hist(no_companions_lens['t_E'], bins = np.logspace(0, 2.5, 15),histtype=u'step', label="Single Lens")
plt.hist(no_companions_source['t_E'], bins = np.logspace(0, 2.5, 15),histtype=u'step', label="Single Source")
plt.hist(companions_lens['t_E'], bins = np.logspace(0, 2.5, 15),histtype=u'step', label="Binary Lens")
plt.hist(companions_source['t_E'], bins = np.logspace(0, 2.5, 15),histtype=u'step', label="Binary Source")
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.xlabel('$t_E$ (days)')
# Out:
# Text(0.5, 0, '$t_E$ (days)')

# %%
single = no_companions_lens[no_companions_lens['N_companions_S'] == 0]
plbs = no_companions_lens[no_companions_lens['N_companions_S'] != 0]
blps = no_companions_source[no_companions_source['N_companions_L'] != 0]
blbs = companions_source[companions_source['N_companions_L'] != 0]

binary = vstack([plbs, blps, blbs])

plt.hist(single['t_E'], bins = np.logspace(0, 2.5, 15),histtype=u'step', label="Single")
plt.hist(binary['t_E'], bins = np.logspace(0, 2.5, 15),histtype=u'step', label="Binary")
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.xlabel('$t_E$ (days)')
# Out:
# Text(0.5, 0, '$t_E$ (days)')

# %%
lens_type={0:'star', 101:'WD', 102:'NS', 103:'BH'}
for rem_id in np.unique(t['rem_id_L']):
    idxs = np.where(t['rem_id_L']==rem_id)[0]
    plt.scatter(t['t_E'][idxs], t['pi_E'][idxs], label=lens_type[rem_id])
plt.xscale('log')
plt.yscale('log')
plt.xlabel('$t_E$ (days)')
plt.ylabel('$\pi_E$')
plt.legend(loc=2)
plt.title('SynthPopSyCLE w kicks (1, -1.2)')
plt.savefig('synthpopsycle_lenstype_multiples.png')

# %%
for rem_id in np.unique(t['rem_id_L']):
    idxs = np.where(t['rem_id_L']==rem_id)[0]
    plt.scatter(t['rad_L'][idxs], t['rad_S'][idxs], label='lens type '+str(rem_id))
plt.xlabel('$d_L$ (kpc)')
plt.ylabel('$d_S$ (kpc)')
plt.legend()
